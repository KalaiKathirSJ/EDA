# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("International_Report_Passengers.csv")

# %%
th=df.head(1000)
th
# Out:
#        data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0    05/01/2014  2014      5       14492     RDU       36      11032    CUN
# 1    06/01/2007  2007      6       13204     MCO       33      16085    YHZ
# 2    12/01/2005  2005     12       11433     DTW       43      10411    AUA
# 3    04/01/2003  2003      4       13487     MSP       63      16304    ZIH
# 4    12/01/2005  2005     12       12016     GUM        5      11138    CRK
# ..          ...   ...    ...         ...     ...      ...        ...    ...
# 995  06/01/2003  2003      6       11423     DSM       61      16217    YUL
# 996  12/01/2006  2006     12       11433     DTW       43      16257    YYC
# 997  04/01/2005  2005      4       13495     MSY       72      11032    CUN
# 998  02/01/2001  2001      2       13930     ORD       41      13605    NAS
# 999  04/01/2001  2001      4       13303     MIA       33      14739    SDQ
#
# ...

# %%
kk=th.head(100)
kk.head()
# Out:
#      data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0  05/01/2014  2014      5       14492     RDU       36      11032    CUN
# 1  06/01/2007  2007      6       13204     MCO       33      16085    YHZ
# 2  12/01/2005  2005     12       11433     DTW       43      10411    AUA
# 3  04/01/2003  2003      4       13487     MSP       63      16304    ZIH
# 4  12/01/2005  2005     12       12016     GUM        5      11138    CRK
#
#    fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 0     148      19534      AM           0.0  Passengers        0.0    315.0
# 1     951      20364      C6           0.0  Passengers        0.0    683.0
# 2     277      20344      RD           1.0  Passengers        0.0   1010.0
# 3     148      20204      MG           1.0  Passengers        0.0    508.0
# 4     766      20312      TZ           1.0  Passengers        0.0     76.0
#
#     Total
# 0   315.0
# 1   683.0
# 2  1010.0
# 3   508.0
# 4    76.0

# %%
kk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data_dte      100 non-null    object
#  1   Year          100 non-null    int64
#  2   Month         100 non-null    int64
#  3   usg_apt_id    100 non-null    int64
#  4   usg_apt       100 non-null    object
#  5   usg_wac       100 non-null    int64
#  6   fg_apt_id     100 non-null    int64
#  7   fg_apt        100 non-null    object
#  8   fg_wac        100 non-null    int64
#  9   airlineid     100 non-null    int64
#  10  carrier       98 non-null     object
#  11  carriergroup  100 non-null    float64
#  12  type          100 non-null    object
#  13  Scheduled     100 non-null    float64
#  14  Charter       100 non-null    float64
#  15  Total         100 non-null    float64
# dtypes: float64(4), int64(7), object(5)
# memory usage: 12.6+ KB

# %%
kk.describe()
# Out:
#               Year      Month    usg_apt_id     usg_wac     fg_apt_id  \
# count   100.000000  100.00000    100.000000  100.000000    100.000000
# mean   2005.060000    6.06000  12767.510000   44.140000  13740.920000
# std       2.834919    3.53859   1529.187356   27.547579   2039.701779
# min    2001.000000    1.00000  10140.000000    1.000000  10148.000000
# 25%    2003.000000    3.00000  11423.000000   22.000000  11784.750000
# 50%    2005.000000    6.00000  13034.000000   40.000000  13605.000000
# 75%    2007.000000    9.00000  13954.250000   64.000000  16097.750000
# max    2014.000000   12.00000  15376.000000   93.000000  16321.000000
#
#            fg_wac     airlineid  carriergroup  Scheduled      Charter  \
# count  100.000000    100.000000    100.000000      100.0   100.000000
# mean   443.720000  20238.180000      0.720000        0.0   704.350000
# std    325.944783    305.079105      0.451261        0.0  1119.601366
# ...

# %%
kk.info("Year")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data_dte      100 non-null    object
#  1   Year          100 non-null    int64
#  2   Month         100 non-null    int64
#  3   usg_apt_id    100 non-null    int64
#  4   usg_apt       100 non-null    object
#  5   usg_wac       100 non-null    int64
#  6   fg_apt_id     100 non-null    int64
#  7   fg_apt        100 non-null    object
#  8   fg_wac        100 non-null    int64
#  9   airlineid     100 non-null    int64
#  10  carrier       98 non-null     object
#  11  carriergroup  100 non-null    float64
#  12  type          100 non-null    object
#  13  Scheduled     100 non-null    float64
#  14  Charter       100 non-null    float64
#  15  Total         100 non-null    float64
# dtypes: float64(4), int64(7), object(5)
# memory usage: 12.6+ KB

# %%
kk.shape
# Out:
# (100, 16)

# %%
kk.airlineid.unique()
# Out:
# array([19534, 20364, 20344, 20204, 20312, 20421, 19704, 21186, 20345,
#        20095, 20401, 20147, 20414, 20203, 20065, 20402, 19930, 20377,
#        20305, 20313, 19917, 20293, 19790, 20207, 19386, 19548, 20423,
#        20375, 19976, 20368, 20415, 19977, 20210, 20359, 20272, 20314,
#        20016, 19869, 20373, 19559, 21080, 19531, 21134, 20399])

# %%
kk.isnull().sum()
# Out:
# data_dte        0
# Year            0
# Month           0
# usg_apt_id      0
# usg_apt         0
# usg_wac         0
# fg_apt_id       0
# fg_apt          0
# fg_wac          0
# airlineid       0
# carrier         2
# carriergroup    0
# type            0
# Scheduled       0
# Charter         0
# Total           0
# dtype: int64

# %%
kk.dropna()
# Out:
#       data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0   05/01/2014  2014      5       14492     RDU       36      11032    CUN
# 1   06/01/2007  2007      6       13204     MCO       33      16085    YHZ
# 2   12/01/2005  2005     12       11433     DTW       43      10411    AUA
# 3   04/01/2003  2003      4       13487     MSP       63      16304    ZIH
# 4   12/01/2005  2005     12       12016     GUM        5      11138    CRK
# ..         ...   ...    ...         ...     ...      ...        ...    ...
# 95  02/01/2008  2008      2       13303     MIA       33      10911    CCS
# 96  06/01/2003  2003      6       11433     DTW       43      13180    MBJ
# 97  06/01/2004  2004      6       10529     BDL       11      11032    CUN
# 98  08/01/2008  2008      8       11433     DTW       43      16271    YYZ
# 99  07/01/2004  2004      7       14057     PDX       92      16257    YYC
#
# ...

# %%
kk.interpolate()
# Out:
#       data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0   05/01/2014  2014      5       14492     RDU       36      11032    CUN
# 1   06/01/2007  2007      6       13204     MCO       33      16085    YHZ
# 2   12/01/2005  2005     12       11433     DTW       43      10411    AUA
# 3   04/01/2003  2003      4       13487     MSP       63      16304    ZIH
# 4   12/01/2005  2005     12       12016     GUM        5      11138    CRK
# ..         ...   ...    ...         ...     ...      ...        ...    ...
# 95  02/01/2008  2008      2       13303     MIA       33      10911    CCS
# 96  06/01/2003  2003      6       11433     DTW       43      13180    MBJ
# 97  06/01/2004  2004      6       10529     BDL       11      11032    CUN
# 98  08/01/2008  2008      8       11433     DTW       43      16271    YYZ
# 99  07/01/2004  2004      7       14057     PDX       92      16257    YYC
#
# ...

# %%
kk.tail()
# Out:
#       data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 95  02/01/2008  2008      2       13303     MIA       33      10911    CCS
# 96  06/01/2003  2003      6       11433     DTW       43      13180    MBJ
# 97  06/01/2004  2004      6       10529     BDL       11      11032    CUN
# 98  08/01/2008  2008      8       11433     DTW       43      16271    YYZ
# 99  07/01/2004  2004      7       14057     PDX       92      16257    YYC
#
#     fg_wac  airlineid carrier  carriergroup        type  Scheduled  Charter  \
# 95     388      20203     FCQ           1.0  Passengers        0.0   3542.0
# 96     243      20147      T9           1.0  Passengers        0.0    683.0
# 97     148      20423      U5           1.0  Passengers        0.0    639.0
# 98     936      20402      GL           1.0  Passengers        0.0     44.0
# 99     916      20203     FCQ           1.0  Passengers        0.0     29.0
#
#      Total
# 95  3542.0
# 96   683.0
# 97   639.0
# ...

# %%
#graph plotting
import matplotlib.pyplot as plt
plt.scatter(kk.carriergroup,kk.fg_apt_id)
plt.show()

# %%
plt.scatter(kk.carriergroup,kk.usg_apt)
plt.scatter(kk.usg_apt,kk.fg_apt_id)
plt.show()

# %%
plt.hist(kk.fg_apt_id)
plt.legend(["bars-id"],loc='upper left')
plt.show()

# %%
plt.plot(kk.Year,kk.carriergroup)
plt.legend(["x-year"],loc='upper right')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.bar(kk.fg_apt_id,kk.usg_wac,color='r')
plt.title("PASSENGERS")
plt.legend(["x-fg_apt_id","y-usg_wac"],loc='upper left')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.stem(kk.usg_apt)
plt.show
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.polar(kk.airlineid)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
pie=kk.usg_apt_id
plt.pie(pie)
plt.show()
